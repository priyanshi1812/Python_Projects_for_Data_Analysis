# %%
# !pip install seaborn  # we use ! in front of pip in jupyter

# %%
# import python libraries

import numpy as np  # It helps us to wrok on array. Basically to perform mathematical operations
import pandas as pd   # It works on data frame i.e tables
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns  # For charts. graphs,etc visualization

# %%
# import csv file
df = pd.read_csv('Sales Data.csv', encoding= 'unicode_escape')
# to avoid encoding error, use 'unicode_escap' ( use r in front of file path to escape error)

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
#drop unrelated/blank columns
df.drop(['Status', 'unnamed1'], axis=1, inplace=True)  # inplace=true means,save the changes that we made in this table

# %%
# to check null value, If it give False means [No null value], true[null value is present]

pd.isnull(df)
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
#check for null values, Sum will return the total of null values 
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# drop null values use function call dropna, it delete null values
df.dropna(inplace=True)

# %%
# change data type. Function use to change data type is "astype"
df['Amount'] = df['Amount'].astype('int')

# %%
# to check the datatype

df['Amount'].dtypes
# Out:
# dtype('int32')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#rename column

df.rename(columns= {'Marital_Status':'Shaadi'})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Shaadi  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28       0
# 1      1000732       Kartik  P00110942      F     26-35   35       1
# 2      1001990        Bindu  P00118542      F     26-35   35       1
# 3      1001425       Sudevi  P00237842      M      0-17   16       0
# 4      1000588         Joni  P00057942      M     26-35   28       1
# ...        ...          ...        ...    ...       ...  ...     ...
# 11246  1000695      Manning  P00296942      M     18-25   19       1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33       0
# 11248  1001209        Oshin  P00201342      F     36-45   40       0
# 11249  1004023       Noonan  P00059442      M     36-45   37       0
# 11250  1002744      Brumley  P00281742      F     18-25   19       0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)

df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
# use describe() for specific columns
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Gender

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = sns.countplot(x = 'Gender',data = df)

# Set the figure size
sns.set(rc={'figure.figsize': (6, 5)})

# Define custom colors for the bars 
custom_colors = ['#FF5733', '#0000FF']  # Add more colors if needed

# Create a countplot with custom bar colors, assign 'Gender' to 'hue', and hide the legend
ax = sns.countplot(x='Gender', data=df, hue='Gender', palette=custom_colors, legend=False)

# Add labels to the bars
for bars in ax.containers:
    ax.bar_label(bars, fmt='%d', label_type='edge', color='black', fontsize=10, weight='bold')

plt.show()

# %%
"""# plotting a bar chart for Gender and it's count

ax = sns.countplot(x = 'Gender',data = df)

for bars in ax.containers:
    ax.bar_label(bars)"""
# Out:
# "# plotting a bar chart for Gender and it's count\n\nax = sns.countplot(x = 'Gender',data = df)\n\nfor bars in ax.containers:\n    ax.bar_label(bars)"

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# Custom labels
custom_labels = ['Female', 'Male']

# Plotting the donut chart
fig, ax = plt.subplots()

# Data preparation
labels = custom_labels #sales_gen['Gender'] 
sizes = sales_gen['Amount']

# colors
colors = ['#FFA500', '#00FF00'] 

# explosion
explode = (0.02, 0.02)

# Plotting the pie chart
wedges, texts, autotexts = ax.pie(sizes,colors=colors,explode=explode, labels=labels, autopct='%1.0f%%', startangle=70, wedgeprops=dict(width=0.6))

# Adding a circle in the center to create a donut chart
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Equal aspect ratio ensures that pie is drawn as a circle
ax.axis('equal')  

plt.title('Sales by Gender')
plt.show()

# %%
# plotting a bar chart for gender vs total amount

sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Gender',y= 'Amount' ,data = sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men*

# %% [markdown]
# ### Age

# %%
ax = sns.countplot(data = df, x = 'Age Group', hue = 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Total Amount vs Age Group
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are of age group between 26-35 yrs female*

# %% [markdown]
# ### State

# %%
# total number of orders from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Orders')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
# total amount/sales from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Amount')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively*

# %% [markdown]
# ### Marital Status

# %%
"""ax = sns.countplot(data = df, x = 'Marital_Status')

sns.set(rc={'figure.figsize':(5,5)})

for bars in ax.containers:
    ax.bar_label(bars)"""
# Out:
# "ax = sns.countplot(data = df, x = 'Marital_Status')\n\nsns.set(rc={'figure.figsize':(5,5)})\n\nfor bars in ax.containers:\n    ax.bar_label(bars)"

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# Replace 0 with 'Single' and 1 with 'Married' in the 'Marital_Status' column
sales_state['Marital_Status'] = sales_state['Marital_Status'].replace({0: 'Married', 1: 'Single'})

# Custom labels for the x-axis
custom_labels = ['Married','Single']

# Set the figure size
sns.set(rc={'figure.figsize': (6, 5)})
# Create the bar plot
sns.barplot(data=sales_state, x='Marital_Status', y='Amount', hue='Gender')

# Set custom labels for the x-axis
plt.xticks(ticks=range(len(custom_labels)), labels=custom_labels, rotation=0)

plt.show()

# %% [markdown]
# *From above graphs we can see that most of the buyers are married (women) and they have high purchasing power*

# %%
"""sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')"""
# Out:
# "sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)\n\nsns.set(rc={'figure.figsize':(6,5)})\nsns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')"

# %% [markdown]
# ### Occupation

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = sns.countplot(data = df, x = 'Occupation')

# Set the figure size
sns.set(rc={'figure.figsize':(20, 5)})

# Create a countplot with 'Occupation' as hue and remove the legend
ax = sns.countplot(data=df, x='Occupation', hue='Occupation', palette='viridis', legend=False)

# Add labels to the bars
for bars in ax.containers:
    ax.bar_label(bars, fmt='%d', label_type='edge', color='black', fontsize=10, weight='bold')

plt.show()

# %%
"""sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Occupation')

for bars in ax.containers:
    ax.bar_label(bars)"""
# Out:
# "sns.set(rc={'figure.figsize':(20,5)})\nax = sns.countplot(data = df, x = 'Occupation')\n\nfor bars in ax.containers:\n    ax.bar_label(bars)"

# %%
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector*

# %% [markdown]
# ### Product Category

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = sns.countplot(data = df, x = 'Product_Category')

# Get the top 5 product categories
top_categories = df['Product_Category'].value_counts().head(5).index

# Filter the DataFrame to include only the top 5 categories
df_top5 = df[df['Product_Category'].isin(top_categories)]

# Set the figure size
sns.set(rc={'figure.figsize': (20, 8)})

# Create a countplot with top 5 categories and a custom color palette
ax = sns.countplot(data=df_top5, x='Product_Category', hue='Product_Category', order=top_categories, palette='Set3', legend=False)

# Set the width of the bars
bar_width = 0.8  # Adjust the value as needed

# Iterate through the bars and set the width
for bar in ax.patches:
    bar.set_width(bar_width)

# Add labels to the bars
for bars in ax.containers:
    ax.bar_label(bars, fmt='%d', label_type='edge', color='black', fontsize=10, weight='bold')

plt.show()

# %%
"""sns.set(rc={'figure.figsize':(20,8)})
ax = sns.countplot(data = df, x = 'Product_Category')

for bars in ax.containers:
    ax.bar_label(bars)"""
# Out:
# "sns.set(rc={'figure.figsize':(20,8)})\nax = sns.countplot(data = df, x = 'Product_Category')\n\nfor bars in ax.containers:\n    ax.bar_label(bars)"

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category*

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
# top 10 most sold products (same thing as above)

fig1, ax1 = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# ## Conclusion:
#
# ###

# %% [markdown]
# *Married women age group 26-35 yrs from UP,  Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category*
